# %% [markdown]
# ## *The missing link:*
# # CAS Applied Data Science Final Project
# # Matthias Rinderknecht
#
# ## Notebook 3: Fine-tune the LLM using the Linktransformer package

# %% [markdown]
# ### Setup and Imports

# %%
# !pip install linktransformer

# %%
##Some imports handy for using dataframes
import linktransformer as lt
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt

# %% [markdown]
# ## Fine-tune the base LLM

# %% [markdown]
# ### Load the training dataframe

# %%
from google.colab import files

# Load training csv
dfTrain = pd.read_csv("/content/BASEC_with_ICTRP_3054x64.csv")

print(dfTrain.head(3))
# Out:
#                   date     basecId         snctpId                whoId  \
# 0  2023-05-12 09:42:27  2018-00636  SNCTP000002906  ACTRN12614000042640
# 1  2017-05-09 15:30:17         NaN  SNCTP000001785  ACTRN12616000648426
# 2  2023-01-13 08:53:20  2021-02281  SNCTP000004755  ACTRN12617000147381
#
#     ECName ecFinalDecisionDate WHO register  flagRareDisease  flagForChildren  \
# 0  EC_EKNZ          2018-07-05        ACTRN                0                0
# 1    EC_TI                 NaN        ACTRN                0                0
# 2    EC_ZH          2022-01-11        ACTRN                0                1
#
#    flagForAdolescents  ...                               publicContactAddress  \
# 0                   0  ...  Cardiology Department\nLevel 2, Westmead Hospi...
# 1                   0  ...  CROSS S.A.Via Lavizzari, 18CH-6850 Mendrisio, ...
# 2                   1  ...                                                NaN
#
# ...

# %%
best_model_path=lt.train_model(
        model_path="sentence-transformers/paraphrase-multilingual-mpnet-base-v2", #the base model used above
        data=dfTrain,
        left_col_names=["layTitle", "layTitle", "disease", "intervention"],
        right_col_names=['scientificTitle', "publicTitle", "healthConditions", "interventions"],
        left_id_name=['whoId'],
        right_id_name=['trialId'],
        log_wandb=False,
        training_args={"num_epochs": 3}
    )
# Out:
# Loading config saved at /usr/local/lib/python3.10/dist-packages/linktransformer/configs/linkage.json
# Using base model: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Currently wandb logging is set to False. Your training run can be logged on wandb by setting log_wandb=True , setting approriate parameters in the config and  making an account on wandb if you don't have one yet
# Testing at end:  True
# Dropping duplicates if any from left + right columns
#  Warning Left columns do not form a unique key, please check the left column names. Drop duplicates before if this was unexpected.
# ...
# Serializing left columns
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# ...

# %% [markdown]
# ### Save the model

# %%
# !zip -r /content/model5.zip /content/models
# Out:
#   adding: content/models/ (stored 0%)
#   adding: content/models/linkage/ (stored 0%)
#   adding: content/models/linkage/LT_training_config.json (deflated 49%)
#   adding: content/models/linkage/sentencepiece.bpe.model (deflated 49%)
#   adding: content/models/linkage/model.safetensors (deflated 9%)
#   adding: content/models/linkage/special_tokens_map.json (deflated 85%)
#   adding: content/models/linkage/eval/ (stored 0%)
#   adding: content/models/linkage/eval/Information-Retrieval_evaluation_eval_results.csv (deflated 71%)
#   adding: content/models/linkage/README.md (deflated 57%)
#   adding: content/models/linkage/config.json (deflated 49%)
#   adding: content/models/linkage/tokenizer.json (deflated 76%)
#   adding: content/models/linkage/tokenizer_config.json (deflated 75%)
#   adding: content/models/linkage/sentence_bert_config.json (deflated 4%)
#   adding: content/models/linkage/modules.json (deflated 53%)
# ...
